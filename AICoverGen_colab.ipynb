# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/SociallyIneptWeeb/AICoverGen/blob/main/AICoverGen_colab.ipynb)

# %% [markdown]
# # AICoverGen WebUI
#
# Simply click `Runtime` in the top navigation bar and `Run all`. Wait for the output of the final cell to show the public gradio url and click on it.

# %%
## for python 3.9 run this cell
# !wget -O mini.sh https://repo.anaconda.com/miniconda/Miniconda3-py39_4.9.2-Linux-x86_64.sh
# !chmod +x mini.sh
# !bash ./mini.sh -b -f -p /usr/local
# !conda install -q -y jupyter
# !conda install -q -y google-colab -c conda-forge
# !python -m ipykernel install --name "py39" --user
# Out:
# --2025-02-03 03:18:47--  https://repo.anaconda.com/miniconda/Miniconda3-py39_4.9.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:20f1, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.32.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61451533 (59M) [application/x-sh]
# Saving to: ‘mini.sh’
#
# mini.sh             100%[===================>]  58.60M   249MB/s    in 0.2s
#
# 2025-02-03 03:18:48 (249 MB/s) - ‘mini.sh’ saved [61451533/61451533]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - brotlipy==0.7.0=py39h27cfd23_1003
#     - ca-certificates==2020.12.8=h06a4308_0
#     - certifi==2020.12.5=py39h06a4308_0
#     - cffi==1.14.4=py39h261ae71_0
#     - chardet==3.0.4=py39h06a4308_1003
#     - conda-package-handling==1.7.2=py39h27cfd23_1
#     - conda==4.9.2=py39h06a4308_0
#     - cryptography==3.3.1=py39h3c74f83_0
#     - idna==2.10=py_0
#     - ld_impl_linux-64==2.33.1=h53a641e_7
#     - libedit==3.1.20191231=h14c3975_1
#     - libffi==3.3=he6710b0_2
#     - libgcc-ng==9.1.0=hdf63c60_0
#     - libstdcxx-ng==9.1.0=hdf63c60_0
#     - ncurses==6.2=he6710b0_1
#     - openssl==1.1.1i=h27cfd23_0
#     - pip==20.3.1=py39h06a4308_0
#     - pycosat==0.6.3=py39h27cfd23_0
#     - pycparser==2.20=py_2
#     - pyopenssl==20.0.0=pyhd3eb1b0_1
#     - pysocks==1.7.1=py39h06a4308_0
#     - python==3.9.1=hdb3f193_2
#     - readline==8.0=h7b6447c_0
#     - requests==2.25.0=pyhd3eb1b0_0
#     - ruamel_yaml==0.15.80=py39h27cfd23_0
#     - setuptools==51.0.0=py39h06a4308_2
#     - six==1.15.0=py39h06a4308_0
#     - sqlite==3.33.0=h62c20be_0
#     - tk==8.6.10=hbc83047_0
#     - tqdm==4.54.1=pyhd3eb1b0_0
#     - tzdata==2020d=h14c3975_0
#     - urllib3==1.25.11=py_0
#     - wheel==0.36.1=pyhd3eb1b0_0
#     - xz==5.2.5=h7b6447c_0
#     - yaml==0.2.5=h7b6447c_0
#     - zlib==1.2.11=h7b6447c_3
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   brotlipy           pkgs/main/linux-64::brotlipy-0.7.0-py39h27cfd23_1003
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2020.12.8-h06a4308_0
#   certifi            pkgs/main/linux-64::certifi-2020.12.5-py39h06a4308_0
#   cffi               pkgs/main/linux-64::cffi-1.14.4-py39h261ae71_0
#   chardet            pkgs/main/linux-64::chardet-3.0.4-py39h06a4308_1003
#   conda              pkgs/main/linux-64::conda-4.9.2-py39h06a4308_0
#   conda-package-han~ pkgs/main/linux-64::conda-package-handling-1.7.2-py39h27cfd23_1
#   cryptography       pkgs/main/linux-64::cryptography-3.3.1-py39h3c74f83_0
#   idna               pkgs/main/noarch::idna-2.10-py_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7
#   libedit            pkgs/main/linux-64::libedit-3.1.20191231-h14c3975_1
#   libffi             pkgs/main/linux-64::libffi-3.3-he6710b0_2
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-9.1.0-hdf63c60_0
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-9.1.0-hdf63c60_0
#   ncurses            pkgs/main/linux-64::ncurses-6.2-he6710b0_1
#   openssl            pkgs/main/linux-64::openssl-1.1.1i-h27cfd23_0
#   pip                pkgs/main/linux-64::pip-20.3.1-py39h06a4308_0
#   pycosat            pkgs/main/linux-64::pycosat-0.6.3-py39h27cfd23_0
#   pycparser          pkgs/main/noarch::pycparser-2.20-py_2
#   pyopenssl          pkgs/main/noarch::pyopenssl-20.0.0-pyhd3eb1b0_1
#   pysocks            pkgs/main/linux-64::pysocks-1.7.1-py39h06a4308_0
#   python             pkgs/main/linux-64::python-3.9.1-hdb3f193_2
#   readline           pkgs/main/linux-64::readline-8.0-h7b6447c_0
#   requests           pkgs/main/noarch::requests-2.25.0-pyhd3eb1b0_0
#   ruamel_yaml        pkgs/main/linux-64::ruamel_yaml-0.15.80-py39h27cfd23_0
#   setuptools         pkgs/main/linux-64::setuptools-51.0.0-py39h06a4308_2
#   six                pkgs/main/linux-64::six-1.15.0-py39h06a4308_0
#   sqlite             pkgs/main/linux-64::sqlite-3.33.0-h62c20be_0
#   tk                 pkgs/main/linux-64::tk-8.6.10-hbc83047_0
#   tqdm               pkgs/main/noarch::tqdm-4.54.1-pyhd3eb1b0_0
#   tzdata             pkgs/main/noarch::tzdata-2020d-h14c3975_0
#   urllib3            pkgs/main/noarch::urllib3-1.25.11-py_0
#   wheel              pkgs/main/noarch::wheel-0.36.1-pyhd3eb1b0_0
#   xz                 pkgs/main/linux-64::xz-5.2.5-h7b6447c_0
#   yaml               pkgs/main/linux-64::yaml-0.2.5-h7b6447c_0
#   zlib               pkgs/main/linux-64::zlib-1.2.11-h7b6447c_3
#
#
# done
# done
# Timer: 00:15:12installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# Timer: 00:15:16done
# Timer: 00:15:20done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - jupyter
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-5.1          |            1_gnu          21 KB
#     anyio-4.6.2                |   py39h06a4308_0         200 KB
#     argon2-cffi-21.3.0         |     pyhd3eb1b0_0          15 KB
#     argon2-cffi-bindings-21.2.0|   py39h5eee18b_1          32 KB
#     asttokens-2.0.5            |     pyhd3eb1b0_0          20 KB
#     async-lru-2.0.4            |   py39h06a4308_0          17 KB
#     attrs-24.3.0               |   py39h06a4308_0         152 KB
#     babel-2.16.0               |   py39h06a4308_0         6.8 MB
#     backcall-0.2.0             |     pyhd3eb1b0_0          13 KB
#     beautifulsoup4-4.12.3      |   py39h06a4308_0         217 KB
#     bleach-6.2.0               |   py39h06a4308_0         281 KB
#     bzip2-1.0.8                |       h5eee18b_6         262 KB
#     c-ares-1.19.1              |       h5eee18b_0         118 KB
#     ca-certificates-2024.12.31 |       h06a4308_0         128 KB
#     certifi-2024.12.14         |   py39h06a4308_0         160 KB
#     cffi-1.17.1                |   py39h1fdaa30_1         249 KB
#     charset-normalizer-3.3.2   |     pyhd3eb1b0_0          44 KB
#     comm-0.2.1                 |   py39h06a4308_0          14 KB
#     cryptography-43.0.3        |   py39h7825ff9_1         1.5 MB
#     cyrus-sasl-2.1.28          |       h52b45da_1         237 KB
#     dbus-1.13.18               |       hb2f20db_0         504 KB
#     debugpy-1.8.11             |   py39h6a678d5_0         2.2 MB
#     decorator-5.1.1            |     pyhd3eb1b0_0          12 KB
#     defusedxml-0.7.1           |     pyhd3eb1b0_0          23 KB
#     exceptiongroup-1.2.0       |   py39h06a4308_0          29 KB
#     executing-0.8.3            |     pyhd3eb1b0_0          18 KB
#     expat-2.6.4                |       h6a678d5_0         180 KB
#     fontconfig-2.14.1          |       h55d465d_3         281 KB
#     freetype-2.12.1            |       h4a9f257_0         626 KB
#     glib-2.78.4                |       h6a678d5_0         508 KB
#     glib-tools-2.78.4          |       h6a678d5_0         115 KB
#     gst-plugins-base-1.14.1    |       h6a678d5_1         2.2 MB
#     gstreamer-1.14.1           |       h5eee18b_1         1.7 MB
#     h11-0.14.0                 |   py39h06a4308_0          89 KB
#     httpcore-1.0.2             |   py39h06a4308_0          82 KB
#     httpx-0.27.0               |   py39h06a4308_0         169 KB
#     icu-73.1                   |       h6a678d5_0        25.9 MB
#     importlib-metadata-8.5.0   |   py39h06a4308_0          44 KB
#     importlib_metadata-8.5.0   |       hd3eb1b0_0           9 KB
#     ipykernel-6.29.5           |   py39h06a4308_1         205 KB
#     ipython-8.15.0             |   py39h06a4308_0         1.1 MB
#     ipywidgets-8.1.5           |   py39h06a4308_0         199 KB
#     jedi-0.19.2                |   py39h06a4308_0         1.1 MB
#     jinja2-3.1.5               |   py39h06a4308_0         274 KB
#     jpeg-9e                    |       h5eee18b_3         262 KB
#     json5-0.9.25               |   py39h06a4308_0          43 KB
#     jsonschema-4.23.0          |   py39h06a4308_0         153 KB
#     jsonschema-specifications-2023.7.1|   py39h06a4308_0          15 KB
#     jupyter-1.1.1              |   py39h06a4308_0           8 KB
#     jupyter-lsp-2.2.0          |   py39h06a4308_0          86 KB
#     jupyter_client-8.6.3       |   py39h06a4308_0         184 KB
#     jupyter_console-6.6.3      |   py39h06a4308_0          44 KB
#     jupyter_core-5.7.2         |   py39h06a4308_0          80 KB
#     jupyter_events-0.10.0      |   py39h06a4308_0          37 KB
#     jupyter_server-2.14.1      |   py39h06a4308_0         494 KB
#     jupyter_server_terminals-0.4.4|   py39h06a4308_1          24 KB
#     jupyterlab-4.3.4           |   py39h06a4308_0         5.2 MB
#     jupyterlab_pygments-0.1.2  |             py_0           8 KB
#     jupyterlab_server-2.27.3   |   py39h06a4308_0          88 KB
#     jupyterlab_widgets-3.0.13  |   py39h06a4308_0         194 KB
#     krb5-1.20.1                |       h143b758_1         1.3 MB
#     libabseil-20240116.2       | cxx17_h6a678d5_0         1.3 MB
#     libclang-14.0.6            |default_hc6dbbc7_2         137 KB
#     libclang13-14.0.6          |default_he11475f_2         9.7 MB
#     libcups-2.4.2              |       h2d74bed_1         4.5 MB
#     libcurl-8.11.1             |       hc9e6f67_0         454 KB
#     libedit-3.1.20230828       |       h5eee18b_0         179 KB
#     libev-4.33                 |       h7f8727e_1         111 KB
#     libffi-3.4.4               |       h6a678d5_1         141 KB
#     libgcc-ng-11.2.0           |       h1234567_1         5.3 MB
#     libglib-2.78.4             |       hdc74915_0         1.5 MB
#     libgomp-11.2.0             |       h1234567_1         474 KB
#     libiconv-1.16              |       h5eee18b_3         759 KB
#     libllvm14-14.0.6           |       hecde1de_4        33.4 MB
#     libnghttp2-1.57.0          |       h2d74bed_0         674 KB
#     libpng-1.6.39              |       h5eee18b_0         304 KB
#     libpq-17.2                 |       hdbd6064_0         2.8 MB
#     libprotobuf-4.25.3         |       he621ea3_0         2.8 MB
#     libsodium-1.0.18           |       h7b6447c_0         244 KB
#     libssh2-1.11.1             |       h251f7ec_0         308 KB
#     libstdcxx-ng-11.2.0        |       h1234567_1         4.7 MB
#     libuuid-1.41.5             |       h5eee18b_0          27 KB
#     libxcb-1.15                |       h7f8727e_0         505 KB
#     libxkbcommon-1.0.1         |       h097e994_2         590 KB
#     libxml2-2.13.5             |       hfdd30dd_0         738 KB
#     lz4-c-1.9.4                |       h6a678d5_1         156 KB
#     markupsafe-2.1.3           |   py39h5eee18b_1          22 KB
#     matplotlib-inline-0.1.6    |   py39h06a4308_0          16 KB
#     mistune-2.0.4              |   py39h06a4308_0          92 KB
#     mysql-8.4.0                |       h29a9f33_1        56.6 MB
#     nbclient-0.8.0             |   py39h06a4308_0          97 KB
#     nbconvert-7.16.5           |       hd3eb1b0_0           7 KB
#     nbconvert-core-7.16.5      |   py39h06a4308_0         477 KB
#     nbconvert-pandoc-7.16.5    |       hd3eb1b0_0           7 KB
#     nbformat-5.10.4            |   py39h06a4308_0         138 KB
#     ncurses-6.4                |       h6a678d5_0         914 KB
#     nest-asyncio-1.6.0         |   py39h06a4308_0          14 KB
#     notebook-7.3.2             |   py39h06a4308_0         5.7 MB
#     notebook-shim-0.2.3        |   py39h06a4308_0          22 KB
#     openldap-2.6.4             |       h42fbc30_0         804 KB
#     openssl-3.0.15             |       h5eee18b_0         5.2 MB
#     overrides-7.4.0            |   py39h06a4308_0          29 KB
#     packaging-24.2             |   py39h06a4308_0         167 KB
#     pandoc-2.12                |       h06a4308_3        10.5 MB
#     pandocfilters-1.5.0        |     pyhd3eb1b0_0          11 KB
#     parso-0.8.4                |   py39h06a4308_0         188 KB
#     pcre2-10.42                |       hebb0a14_1         1.3 MB
#     pexpect-4.8.0              |     pyhd3eb1b0_3          53 KB
#     pickleshare-0.7.5          |  pyhd3eb1b0_1003          13 KB
#     platformdirs-3.10.0        |   py39h06a4308_0          33 KB
#     ply-3.11                   |   py39h06a4308_0          81 KB
#     prometheus_client-0.21.0   |   py39h06a4308_0          94 KB
#     prompt-toolkit-3.0.43      |   py39h06a4308_0         571 KB
#     prompt_toolkit-3.0.43      |       hd3eb1b0_0           5 KB
#     psutil-5.9.0               |   py39h5eee18b_1         358 KB
#     ptyprocess-0.7.0           |     pyhd3eb1b0_2          17 KB
#     pure_eval-0.2.2            |     pyhd3eb1b0_0          14 KB
#     pygments-2.15.1            |   py39h06a4308_1         1.7 MB
#     pyopenssl-24.2.1           |   py39h06a4308_0          96 KB
#     pyqt-5.15.10               |   py39h6a678d5_1         5.7 MB
#     pyqt5-sip-12.13.0          |   py39h5eee18b_1          97 KB
#     python-3.9.21              |       he870216_1        25.1 MB
#     python-dateutil-2.9.0post0 |   py39h06a4308_2         279 KB
#     python-fastjsonschema-2.20.0|   py39h06a4308_0         249 KB
#     python-json-logger-3.2.1   |   py39h06a4308_0          24 KB
#     pyyaml-6.0.2               |   py39h5eee18b_0         192 KB
#     pyzmq-26.2.0               |   py39h6a678d5_0         347 KB
#     qt-main-5.15.2             |      hb6262e9_11        53.7 MB
#     qtconsole-5.6.1            |   py39h06a4308_0         204 KB
#     qtpy-2.4.1                 |   py39h06a4308_0         107 KB
#     readline-8.2               |       h5eee18b_0         357 KB
#     referencing-0.30.2         |   py39h06a4308_0          61 KB
#     requests-2.32.3            |   py39h06a4308_1          99 KB
#     rfc3339-validator-0.1.4    |   py39h06a4308_0           9 KB
#     rfc3986-validator-0.1.1    |   py39h06a4308_0           9 KB
#     rpds-py-0.22.3             |   py39h4aa5aa6_0         369 KB
#     send2trash-1.8.2           |   py39h06a4308_1          27 KB
#     sip-6.7.12                 |   py39h6a678d5_1         510 KB
#     sniffio-1.3.0              |   py39h06a4308_0          16 KB
#     soupsieve-2.5              |   py39h06a4308_0          69 KB
#     sqlite-3.45.3              |       h5eee18b_0         1.2 MB
#     stack_data-0.2.0           |     pyhd3eb1b0_0          22 KB
#     terminado-0.17.1           |   py39h06a4308_0          31 KB
#     tinycss2-1.4.0             |   py39h06a4308_0          96 KB
#     tk-8.6.14                  |       h39e8969_0         3.4 MB
#     tomli-2.0.1                |   py39h06a4308_0          24 KB
#     tornado-6.4.2              |   py39h5eee18b_0         646 KB
#     traitlets-5.14.3           |   py39h06a4308_0         179 KB
#     typing-extensions-4.12.2   |   py39h06a4308_0           9 KB
#     typing_extensions-4.12.2   |   py39h06a4308_0          64 KB
#     wcwidth-0.2.5              |     pyhd3eb1b0_0          26 KB
#     webencodings-0.5.1         |   py39h06a4308_1          20 KB
#     websocket-client-1.8.0     |   py39h06a4308_0          89 KB
#     widgetsnbextension-4.0.13  |   py39h06a4308_0         967 KB
#     xz-5.4.6                   |       h5eee18b_1         643 KB
#     zeromq-4.3.5               |       h6a678d5_0         366 KB
#     zipp-3.21.0                |   py39h06a4308_0          26 KB
#     zlib-1.2.13                |       h5eee18b_1         111 KB
#     zstd-1.5.6                 |       hc292b87_0         664 KB
#     ------------------------------------------------------------
#                                            Total:       309.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-1_gnu
#   anyio              pkgs/main/linux-64::anyio-4.6.2-py39h06a4308_0
#   argon2-cffi        pkgs/main/noarch::argon2-cffi-21.3.0-pyhd3eb1b0_0
#   argon2-cffi-bindi~ pkgs/main/linux-64::argon2-cffi-bindings-21.2.0-py39h5eee18b_1
#   asttokens          pkgs/main/noarch::asttokens-2.0.5-pyhd3eb1b0_0
#   async-lru          pkgs/main/linux-64::async-lru-2.0.4-py39h06a4308_0
#   attrs              pkgs/main/linux-64::attrs-24.3.0-py39h06a4308_0
#   babel              pkgs/main/linux-64::babel-2.16.0-py39h06a4308_0
#   backcall           pkgs/main/noarch::backcall-0.2.0-pyhd3eb1b0_0
#   beautifulsoup4     pkgs/main/linux-64::beautifulsoup4-4.12.3-py39h06a4308_0
#   bleach             pkgs/main/linux-64::bleach-6.2.0-py39h06a4308_0
#   bzip2              pkgs/main/linux-64::bzip2-1.0.8-h5eee18b_6
#   c-ares             pkgs/main/linux-64::c-ares-1.19.1-h5eee18b_0
#   charset-normalizer pkgs/main/noarch::charset-normalizer-3.3.2-pyhd3eb1b0_0
#   comm               pkgs/main/linux-64::comm-0.2.1-py39h06a4308_0
#   cyrus-sasl         pkgs/main/linux-64::cyrus-sasl-2.1.28-h52b45da_1
#   dbus               pkgs/main/linux-64::dbus-1.13.18-hb2f20db_0
#   debugpy            pkgs/main/linux-64::debugpy-1.8.11-py39h6a678d5_0
#   decorator          pkgs/main/noarch::decorator-5.1.1-pyhd3eb1b0_0
#   defusedxml         pkgs/main/noarch::defusedxml-0.7.1-pyhd3eb1b0_0
#   exceptiongroup     pkgs/main/linux-64::exceptiongroup-1.2.0-py39h06a4308_0
#   executing          pkgs/main/noarch::executing-0.8.3-pyhd3eb1b0_0
#   expat              pkgs/main/linux-64::expat-2.6.4-h6a678d5_0
#   fontconfig         pkgs/main/linux-64::fontconfig-2.14.1-h55d465d_3
#   freetype           pkgs/main/linux-64::freetype-2.12.1-h4a9f257_0
#   glib               pkgs/main/linux-64::glib-2.78.4-h6a678d5_0
#   glib-tools         pkgs/main/linux-64::glib-tools-2.78.4-h6a678d5_0
#   gst-plugins-base   pkgs/main/linux-64::gst-plugins-base-1.14.1-h6a678d5_1
#   gstreamer          pkgs/main/linux-64::gstreamer-1.14.1-h5eee18b_1
#   h11                pkgs/main/linux-64::h11-0.14.0-py39h06a4308_0
#   httpcore           pkgs/main/linux-64::httpcore-1.0.2-py39h06a4308_0
#   httpx              pkgs/main/linux-64::httpx-0.27.0-py39h06a4308_0
#   icu                pkgs/main/linux-64::icu-73.1-h6a678d5_0
#   importlib-metadata pkgs/main/linux-64::importlib-metadata-8.5.0-py39h06a4308_0
#   importlib_metadata pkgs/main/noarch::importlib_metadata-8.5.0-hd3eb1b0_0
#   ipykernel          pkgs/main/linux-64::ipykernel-6.29.5-py39h06a4308_1
#   ipython            pkgs/main/linux-64::ipython-8.15.0-py39h06a4308_0
#   ipywidgets         pkgs/main/linux-64::ipywidgets-8.1.5-py39h06a4308_0
#   jedi               pkgs/main/linux-64::jedi-0.19.2-py39h06a4308_0
#   jinja2             pkgs/main/linux-64::jinja2-3.1.5-py39h06a4308_0
#   jpeg               pkgs/main/linux-64::jpeg-9e-h5eee18b_3
#   json5              pkgs/main/linux-64::json5-0.9.25-py39h06a4308_0
#   jsonschema         pkgs/main/linux-64::jsonschema-4.23.0-py39h06a4308_0
#   jsonschema-specif~ pkgs/main/linux-64::jsonschema-specifications-2023.7.1-py39h06a4308_0
#   jupyter            pkgs/main/linux-64::jupyter-1.1.1-py39h06a4308_0
#   jupyter-lsp        pkgs/main/linux-64::jupyter-lsp-2.2.0-py39h06a4308_0
#   jupyter_client     pkgs/main/linux-64::jupyter_client-8.6.3-py39h06a4308_0
#   jupyter_console    pkgs/main/linux-64::jupyter_console-6.6.3-py39h06a4308_0
#   jupyter_core       pkgs/main/linux-64::jupyter_core-5.7.2-py39h06a4308_0
#   jupyter_events     pkgs/main/linux-64::jupyter_events-0.10.0-py39h06a4308_0
#   jupyter_server     pkgs/main/linux-64::jupyter_server-2.14.1-py39h06a4308_0
#   jupyter_server_te~ pkgs/main/linux-64::jupyter_server_terminals-0.4.4-py39h06a4308_1
#   jupyterlab         pkgs/main/linux-64::jupyterlab-4.3.4-py39h06a4308_0
#   jupyterlab_pygmen~ pkgs/main/noarch::jupyterlab_pygments-0.1.2-py_0
#   jupyterlab_server  pkgs/main/linux-64::jupyterlab_server-2.27.3-py39h06a4308_0
#   jupyterlab_widgets pkgs/main/linux-64::jupyterlab_widgets-3.0.13-py39h06a4308_0
#   krb5               pkgs/main/linux-64::krb5-1.20.1-h143b758_1
#   libabseil          pkgs/main/linux-64::libabseil-20240116.2-cxx17_h6a678d5_0
#   libclang           pkgs/main/linux-64::libclang-14.0.6-default_hc6dbbc7_2
#   libclang13         pkgs/main/linux-64::libclang13-14.0.6-default_he11475f_2
#   libcups            pkgs/main/linux-64::libcups-2.4.2-h2d74bed_1
#   libcurl            pkgs/main/linux-64::libcurl-8.11.1-hc9e6f67_0
#   libev              pkgs/main/linux-64::libev-4.33-h7f8727e_1
#   libglib            pkgs/main/linux-64::libglib-2.78.4-hdc74915_0
#   libgomp            pkgs/main/linux-64::libgomp-11.2.0-h1234567_1
#   libiconv           pkgs/main/linux-64::libiconv-1.16-h5eee18b_3
#   libllvm14          pkgs/main/linux-64::libllvm14-14.0.6-hecde1de_4
#   libnghttp2         pkgs/main/linux-64::libnghttp2-1.57.0-h2d74bed_0
#   libpng             pkgs/main/linux-64::libpng-1.6.39-h5eee18b_0
#   libpq              pkgs/main/linux-64::libpq-17.2-hdbd6064_0
#   libprotobuf        pkgs/main/linux-64::libprotobuf-4.25.3-he621ea3_0
#   libsodium          pkgs/main/linux-64::libsodium-1.0.18-h7b6447c_0
#   libssh2            pkgs/main/linux-64::libssh2-1.11.1-h251f7ec_0
#   libuuid            pkgs/main/linux-64::libuuid-1.41.5-h5eee18b_0
#   libxcb             pkgs/main/linux-64::libxcb-1.15-h7f8727e_0
#   libxkbcommon       pkgs/main/linux-64::libxkbcommon-1.0.1-h097e994_2
#   libxml2            pkgs/main/linux-64::libxml2-2.13.5-hfdd30dd_0
#   lz4-c              pkgs/main/linux-64::lz4-c-1.9.4-h6a678d5_1
#   markupsafe         pkgs/main/linux-64::markupsafe-2.1.3-py39h5eee18b_1
#   matplotlib-inline  pkgs/main/linux-64::matplotlib-inline-0.1.6-py39h06a4308_0
#   mistune            pkgs/main/linux-64::mistune-2.0.4-py39h06a4308_0
#   mysql              pkgs/main/linux-64::mysql-8.4.0-h29a9f33_1
#   nbclient           pkgs/main/linux-64::nbclient-0.8.0-py39h06a4308_0
#   nbconvert          pkgs/main/noarch::nbconvert-7.16.5-hd3eb1b0_0
#   nbconvert-core     pkgs/main/linux-64::nbconvert-core-7.16.5-py39h06a4308_0
#   nbconvert-pandoc   pkgs/main/noarch::nbconvert-pandoc-7.16.5-hd3eb1b0_0
#   nbformat           pkgs/main/linux-64::nbformat-5.10.4-py39h06a4308_0
#   nest-asyncio       pkgs/main/linux-64::nest-asyncio-1.6.0-py39h06a4308_0
#   notebook           pkgs/main/linux-64::notebook-7.3.2-py39h06a4308_0
#   notebook-shim      pkgs/main/linux-64::notebook-shim-0.2.3-py39h06a4308_0
#   openldap           pkgs/main/linux-64::openldap-2.6.4-h42fbc30_0
#   overrides          pkgs/main/linux-64::overrides-7.4.0-py39h06a4308_0
#   packaging          pkgs/main/linux-64::packaging-24.2-py39h06a4308_0
#   pandoc             pkgs/main/linux-64::pandoc-2.12-h06a4308_3
#   pandocfilters      pkgs/main/noarch::pandocfilters-1.5.0-pyhd3eb1b0_0
#   parso              pkgs/main/linux-64::parso-0.8.4-py39h06a4308_0
#   pcre2              pkgs/main/linux-64::pcre2-10.42-hebb0a14_1
#   pexpect            pkgs/main/noarch::pexpect-4.8.0-pyhd3eb1b0_3
#   pickleshare        pkgs/main/noarch::pickleshare-0.7.5-pyhd3eb1b0_1003
#   platformdirs       pkgs/main/linux-64::platformdirs-3.10.0-py39h06a4308_0
#   ply                pkgs/main/linux-64::ply-3.11-py39h06a4308_0
#   prometheus_client  pkgs/main/linux-64::prometheus_client-0.21.0-py39h06a4308_0
#   prompt-toolkit     pkgs/main/linux-64::prompt-toolkit-3.0.43-py39h06a4308_0
#   prompt_toolkit     pkgs/main/noarch::prompt_toolkit-3.0.43-hd3eb1b0_0
#   psutil             pkgs/main/linux-64::psutil-5.9.0-py39h5eee18b_1
#   ptyprocess         pkgs/main/noarch::ptyprocess-0.7.0-pyhd3eb1b0_2
#   pure_eval          pkgs/main/noarch::pure_eval-0.2.2-pyhd3eb1b0_0
#   pygments           pkgs/main/linux-64::pygments-2.15.1-py39h06a4308_1
#   pyqt               pkgs/main/linux-64::pyqt-5.15.10-py39h6a678d5_1
#   pyqt5-sip          pkgs/main/linux-64::pyqt5-sip-12.13.0-py39h5eee18b_1
#   python-dateutil    pkgs/main/linux-64::python-dateutil-2.9.0post0-py39h06a4308_2
#   python-fastjsonsc~ pkgs/main/linux-64::python-fastjsonschema-2.20.0-py39h06a4308_0
#   python-json-logger pkgs/main/linux-64::python-json-logger-3.2.1-py39h06a4308_0
#   pyyaml             pkgs/main/linux-64::pyyaml-6.0.2-py39h5eee18b_0
#   pyzmq              pkgs/main/linux-64::pyzmq-26.2.0-py39h6a678d5_0
#   qt-main            pkgs/main/linux-64::qt-main-5.15.2-hb6262e9_11
#   qtconsole          pkgs/main/linux-64::qtconsole-5.6.1-py39h06a4308_0
#   qtpy               pkgs/main/linux-64::qtpy-2.4.1-py39h06a4308_0
#   referencing        pkgs/main/linux-64::referencing-0.30.2-py39h06a4308_0
#   rfc3339-validator  pkgs/main/linux-64::rfc3339-validator-0.1.4-py39h06a4308_0
#   rfc3986-validator  pkgs/main/linux-64::rfc3986-validator-0.1.1-py39h06a4308_0
#   rpds-py            pkgs/main/linux-64::rpds-py-0.22.3-py39h4aa5aa6_0
#   send2trash         pkgs/main/linux-64::send2trash-1.8.2-py39h06a4308_1
#   sip                pkgs/main/linux-64::sip-6.7.12-py39h6a678d5_1
#   sniffio            pkgs/main/linux-64::sniffio-1.3.0-py39h06a4308_0
#   soupsieve          pkgs/main/linux-64::soupsieve-2.5-py39h06a4308_0
#   stack_data         pkgs/main/noarch::stack_data-0.2.0-pyhd3eb1b0_0
#   terminado          pkgs/main/linux-64::terminado-0.17.1-py39h06a4308_0
#   tinycss2           pkgs/main/linux-64::tinycss2-1.4.0-py39h06a4308_0
#   tomli              pkgs/main/linux-64::tomli-2.0.1-py39h06a4308_0
#   tornado            pkgs/main/linux-64::tornado-6.4.2-py39h5eee18b_0
#   traitlets          pkgs/main/linux-64::traitlets-5.14.3-py39h06a4308_0
#   typing-extensions  pkgs/main/linux-64::typing-extensions-4.12.2-py39h06a4308_0
#   typing_extensions  pkgs/main/linux-64::typing_extensions-4.12.2-py39h06a4308_0
#   wcwidth            pkgs/main/noarch::wcwidth-0.2.5-pyhd3eb1b0_0
#   webencodings       pkgs/main/linux-64::webencodings-0.5.1-py39h06a4308_1
#   websocket-client   pkgs/main/linux-64::websocket-client-1.8.0-py39h06a4308_0
#   widgetsnbextension pkgs/main/linux-64::widgetsnbextension-4.0.13-py39h06a4308_0
#   zeromq             pkgs/main/linux-64::zeromq-4.3.5-h6a678d5_0
#   zipp               pkgs/main/linux-64::zipp-3.21.0-py39h06a4308_0
#   zstd               pkgs/main/linux-64::zstd-1.5.6-hc292b87_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2020.12.8-h06a4308_0 --> 2024.12.31-h06a4308_0
#   certifi                          2020.12.5-py39h06a4308_0 --> 2024.12.14-py39h06a4308_0
#   cffi                                1.14.4-py39h261ae71_0 --> 1.17.1-py39h1fdaa30_1
#   cryptography                         3.3.1-py39h3c74f83_0 --> 43.0.3-py39h7825ff9_1
#   libedit                           3.1.20191231-h14c3975_1 --> 3.1.20230828-h5eee18b_0
#   libffi                                     3.3-he6710b0_2 --> 3.4.4-h6a678d5_1
#   libgcc-ng                                9.1.0-hdf63c60_0 --> 11.2.0-h1234567_1
#   libstdcxx-ng                             9.1.0-hdf63c60_0 --> 11.2.0-h1234567_1
#   ncurses                                    6.2-he6710b0_1 --> 6.4-h6a678d5_0
#   openssl                                 1.1.1i-h27cfd23_0 --> 3.0.15-h5eee18b_0
#   pyopenssl          pkgs/main/noarch::pyopenssl-20.0.0-py~ --> pkgs/main/linux-64::pyopenssl-24.2.1-py39h06a4308_0
#   python                                   3.9.1-hdb3f193_2 --> 3.9.21-he870216_1
#   readline                                   8.0-h7b6447c_0 --> 8.2-h5eee18b_0
#   requests           pkgs/main/noarch::requests-2.25.0-pyh~ --> pkgs/main/linux-64::requests-2.32.3-py39h06a4308_1
#   sqlite                                  3.33.0-h62c20be_0 --> 3.45.3-h5eee18b_0
#   tk                                      8.6.10-hbc83047_0 --> 8.6.14-h39e8969_0
#   xz                                       5.2.5-h7b6447c_0 --> 5.4.6-h5eee18b_1
#   zlib                                    1.2.11-h7b6447c_3 --> 1.2.13-h5eee18b_1
#
#
# Timer: 00:15:55done
# Timer: 00:16:02done
# Timer: 00:16:05done
# Timer: 00:16:30done
# Timer: 00:17:43done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - google-colab
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aiohappyeyeballs-2.4.4     |     pyhd8ed1ab_1          19 KB  conda-forge
#     aiohttp-3.10.5             |   py39h5eee18b_0         736 KB
#     aiosignal-1.3.2            |     pyhd8ed1ab_0          13 KB  conda-forge
#     async-timeout-4.0.3        |     pyhd8ed1ab_0          11 KB  conda-forge
#     ca-certificates-2025.1.31  |       hbcca054_0         154 KB  conda-forge
#     cachetools-5.5.1           |     pyhd8ed1ab_0          15 KB  conda-forge
#     certifi-2024.12.14         |     pyhd8ed1ab_0         158 KB  conda-forge
#     conda-22.11.1              |   py39hf3d152e_1         904 KB  conda-forge
#     frozenlist-1.5.0           |   py39h5eee18b_0          58 KB
#     google-auth-2.38.0         |     pyhd8ed1ab_0         114 KB  conda-forge
#     google-colab-1.0.0         |     pyh44b312d_0          77 KB  conda-forge
#     libblas-3.9.0              |       8_openblas          11 KB  conda-forge
#     libcblas-3.9.0             |       8_openblas          11 KB  conda-forge
#     libgfortran-ng-7.5.0       |      h14aa051_20          23 KB  conda-forge
#     libgfortran4-7.5.0         |      h14aa051_20         1.2 MB  conda-forge
#     liblapack-3.9.0            |       8_openblas          11 KB  conda-forge
#     libopenblas-0.3.12         |pthreads_hb3c22a3_1         8.2 MB  conda-forge
#     multidict-6.1.0            |   py39h5eee18b_0          55 KB
#     numpy-1.22.3               |   py39hc58783e_2         6.8 MB  conda-forge
#     pandas-1.2.3               |   py39hde0f152_0        12.1 MB  conda-forge
#     pluggy-1.5.0               |     pyhd8ed1ab_1          23 KB  conda-forge
#     portpicker-1.6.0           |     pyhd8ed1ab_2          20 KB  conda-forge
#     pyasn1-0.6.1               |     pyhd8ed1ab_2          61 KB  conda-forge
#     pyasn1-modules-0.4.1       |     pyhd8ed1ab_1          94 KB  conda-forge
#     python_abi-3.9             |           2_cp39           4 KB  conda-forge
#     pytz-2025.1                |     pyhd8ed1ab_0         182 KB  conda-forge
#     pyu2f-0.1.5                |     pyhd8ed1ab_1          36 KB  conda-forge
#     rsa-4.9                    |     pyhd8ed1ab_1          30 KB  conda-forge
#     ruamel.yaml-0.17.21        |   py39hb9d737c_1         172 KB  conda-forge
#     ruamel.yaml.clib-0.2.8     |   py39h5eee18b_0         158 KB
#     toolz-1.0.0                |     pyhd8ed1ab_1          51 KB  conda-forge
#     yarl-1.7.2                 |   py39hb9d737c_2         132 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        31.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   aiohappyeyeballs   conda-forge/noarch::aiohappyeyeballs-2.4.4-pyhd8ed1ab_1
#   aiohttp            pkgs/main/linux-64::aiohttp-3.10.5-py39h5eee18b_0
#   aiosignal          conda-forge/noarch::aiosignal-1.3.2-pyhd8ed1ab_0
#   async-timeout      conda-forge/noarch::async-timeout-4.0.3-pyhd8ed1ab_0
#   cachetools         conda-forge/noarch::cachetools-5.5.1-pyhd8ed1ab_0
#   frozenlist         pkgs/main/linux-64::frozenlist-1.5.0-py39h5eee18b_0
#   google-auth        conda-forge/noarch::google-auth-2.38.0-pyhd8ed1ab_0
#   google-colab       conda-forge/noarch::google-colab-1.0.0-pyh44b312d_0
#   libblas            conda-forge/linux-64::libblas-3.9.0-8_openblas
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-8_openblas
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-7.5.0-h14aa051_20
#   libgfortran4       conda-forge/linux-64::libgfortran4-7.5.0-h14aa051_20
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-8_openblas
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.12-pthreads_hb3c22a3_1
#   multidict          pkgs/main/linux-64::multidict-6.1.0-py39h5eee18b_0
#   numpy              conda-forge/linux-64::numpy-1.22.3-py39hc58783e_2
#   pandas             conda-forge/linux-64::pandas-1.2.3-py39hde0f152_0
#   pluggy             conda-forge/noarch::pluggy-1.5.0-pyhd8ed1ab_1
#   portpicker         conda-forge/noarch::portpicker-1.6.0-pyhd8ed1ab_2
#   pyasn1             conda-forge/noarch::pyasn1-0.6.1-pyhd8ed1ab_2
#   pyasn1-modules     conda-forge/noarch::pyasn1-modules-0.4.1-pyhd8ed1ab_1
#   python_abi         conda-forge/linux-64::python_abi-3.9-2_cp39
#   pytz               conda-forge/noarch::pytz-2025.1-pyhd8ed1ab_0
#   pyu2f              conda-forge/noarch::pyu2f-0.1.5-pyhd8ed1ab_1
#   rsa                conda-forge/noarch::rsa-4.9-pyhd8ed1ab_1
#   ruamel.yaml        conda-forge/linux-64::ruamel.yaml-0.17.21-py39hb9d737c_1
#   ruamel.yaml.clib   pkgs/main/linux-64::ruamel.yaml.clib-0.2.8-py39h5eee18b_0
#   toolz              conda-forge/noarch::toolz-1.0.0-pyhd8ed1ab_1
#   yarl               conda-forge/linux-64::yarl-1.7.2-py39hb9d737c_2
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2024.12.31~ --> conda-forge::ca-certificates-2025.1.31-hbcca054_0
#   conda               pkgs/main::conda-4.9.2-py39h06a4308_0 --> conda-forge::conda-22.11.1-py39hf3d152e_1
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            pkgs/main/linux-64::certifi-2024.12.1~ --> conda-forge/noarch::certifi-2024.12.14-pyhd8ed1ab_0
#
#
# Timer: 00:17:54Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Timer: 00:17:55done
# Timer: 00:17:58Installed kernelspec py39 in /root/.local/share/jupyter/kernels/py39

# %%
! python3 --version
# Out:
# Python 3.9.21

# %%
#@title Clone repository
from IPython.display import clear_output
import codecs
import threading
import time
cloneing=codecs.decode('uggcf://tvguho.pbz/FbpvnyylVarcgJrro/NVPbireTra.tvg','rot_13')
# !git clone $cloneing HRVC
def update_timer_and_print():
    global timer
    while True:
        hours, remainder = divmod(timer, 3600)
        minutes, seconds = divmod(remainder, 60)
        timer_str = f'{hours:02}:{minutes:02}:{seconds:02}'
        print(f'\rTimer: {timer_str}', end='', flush=True)  # Print without a newline
        time.sleep(1)
        timer += 1
timer = 0
threading.Thread(target=update_timer_and_print, daemon=True).start()
# %cd HRVC
clear_output()
print("Done Cloning Repository")
# Out:
# Done Cloning Repository

# %%
#@title Install requirements
# !pip install pip==23.3.1
# !pip install -q -r requirements.txt
# !pip install gradio-client==0.8.1
# !pip install gradio==3.48.0
# install cuda fix
# !python -m pip install ort-nightly-gpu --index-url=https://aiinfra.pkgs.visualstudio.com/PublicPackages/_packaging/ort-cuda-12-nightly/pypi/simple/
clear_output()
print("Finished Installing Requirements")
# !sudo apt update
clear_output()
print("Finished Updating")
# !sudo apt install sox
clear_output()
print("Finished running this cell, proceed to the next cell")
# Out:
# Finished running this cell, proceed to the next cell

# %%
#@title Download MDXNet Vocal Separation and Hubert Base Models
models=codecs.decode('fep/qbjaybnq_zbqryf.cl','rot_13')
# !python $models
clear_output()
print("Finished Downloading Voice Separation Model and Hubert Base Model")
# Out:
# Finished Downloading Voice Separation Model and Hubert Base Model

# %%
#@title Run WebUI
runpice=codecs.decode('fep/jrohv.cl','rot_13')
# !python $runpice --share
# Out:
# Timer: 00:57:142025-02-03 03:50:49 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# Timer: 00:57:162025-02-03 03:50:50 | INFO | faiss.loader | Loading faiss with AVX2 support.
# 2025-02-03 03:50:50 | INFO | faiss.loader | Successfully loaded faiss with AVX2 support.
# IMPORTANT: You are using gradio version 3.48.0, however version 4.44.1 is available, please upgrade.
# --------
# Running on local URL:  http://127.0.0.1:7860
# Timer: 00:57:18Running on public URL: https://52ff3fd78159ea26b3.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# Timer: 01:03:34Traceback (most recent call last):
#   File "/content/HRVC/HRVC/src/webui.py", line 81, in download_online_model
#     urllib.request.urlretrieve(url, zip_name)
#   File "/usr/local/lib/python3.9/urllib/request.py", line 239, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "/usr/local/lib/python3.9/urllib/request.py", line 214, in urlopen
#     return opener.open(url, data, timeout)
#   File "/usr/local/lib/python3.9/urllib/request.py", line 523, in open
#     response = meth(req, response)
#   File "/usr/local/lib/python3.9/urllib/request.py", line 632, in http_response
#     response = self.parent.error(
#   File "/usr/local/lib/python3.9/urllib/request.py", line 561, in error
#     return self._call_chain(*args)
#   File "/usr/local/lib/python3.9/urllib/request.py", line 494, in _call_chain
#     result = func(*args)
#   File "/usr/local/lib/python3.9/urllib/request.py", line 641, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 404: Not Found
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/gradio/queueing.py", line 407, in call_prediction
#     output = await route_utils.call_process_api(
#   File "/usr/local/lib/python3.9/site-packages/gradio/route_utils.py", line 226, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/usr/local/lib/python3.9/site-packages/gradio/blocks.py", line 1550, in process_api
#     result = await self.call_function(
#   File "/usr/local/lib/python3.9/site-packages/gradio/blocks.py", line 1185, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "/usr/local/lib/python3.9/site-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/usr/local/lib/python3.9/site-packages/anyio/_backends/_asyncio.py", line 2364, in run_sync_in_worker_thread
#     return await future
#   File "/usr/local/lib/python3.9/site-packages/anyio/_backends/_asyncio.py", line 864, in run
#     result = context.run(func, *args)
#   File "/usr/local/lib/python3.9/site-packages/gradio/utils.py", line 661, in wrapper
#     response = f(*args, **kwargs)
#   File "/content/HRVC/HRVC/src/webui.py", line 88, in download_online_model
#     raise gr.Error(str(e))
# gradio.exceptions.Error: 'HTTP Error 404: Not Found'
# 100% 6/6 [00:02<00:00,  2.40it/s]
# 100% 6/6 [00:01<00:00,  3.80it/s]
# 100% 6/6 [00:01<00:00,  4.35it/s]
# 100% 6/6 [00:01<00:00,  4.00it/s]
# 100% 4/4 [00:02<00:00,  1.83it/s]
# 100% 4/4 [00:02<00:00,  1.91it/s]
# 2025-02-03 03:55:16 | INFO | fairseq.tasks.hubert_pretraining | current directory is /content/HRVC/HRVC
# 2025-02-03 03:55:16 | INFO | fairseq.tasks.hubert_pretraining | HubertPretrainingTask Config {'_name': 'hubert_pretraining', 'data': 'metadata', 'fine_tuning': False, 'labels': ['km'], 'label_dir': 'label', 'label_rate': 50.0, 'sample_rate': 16000, 'normalize': False, 'enable_padding': False, 'max_keep_size': None, 'max_sample_size': 250000, 'min_sample_size': 32000, 'single_target': False, 'random_crop': True, 'pad_audio': False}
# 2025-02-03 03:55:16 | INFO | fairseq.models.hubert.hubert | HubertModel Config: {'_name': 'hubert', 'label_rate': 50.0, 'extractor_mode': default, 'encoder_layers': 12, 'encoder_embed_dim': 768, 'encoder_ffn_embed_dim': 3072, 'encoder_attention_heads': 12, 'activation_fn': gelu, 'layer_type': transformer, 'dropout': 0.1, 'attention_dropout': 0.1, 'activation_dropout': 0.0, 'encoder_layerdrop': 0.05, 'dropout_input': 0.1, 'dropout_features': 0.1, 'final_dim': 256, 'untie_final_proj': True, 'layer_norm_first': False, 'conv_feature_layers': '[(512,10,5)] + [(512,3,2)] * 4 + [(512,2,2)] * 2', 'conv_bias': False, 'logit_temp': 0.1, 'target_glu': False, 'feature_grad_mult': 0.1, 'mask_length': 10, 'mask_prob': 0.8, 'mask_selection': static, 'mask_other': 0.0, 'no_mask_overlap': False, 'mask_min_space': 1, 'mask_channel_length': 10, 'mask_channel_prob': 0.0, 'mask_channel_selection': static, 'mask_channel_other': 0.0, 'no_mask_channel_overlap': False, 'mask_channel_min_space': 1, 'conv_pos': 128, 'conv_pos_groups': 16, 'latent_temp': [2.0, 0.5, 0.999995], 'skip_masked': False, 'skip_nomask': False, 'checkpoint_activations': False, 'required_seq_len_multiple': 2, 'depthwise_conv_kernel_size': 31, 'attn_type': '', 'pos_enc_type': 'abs', 'fp16': False}
# Timer: 01:06:12gin_channels: 256 self.spk_embed_dim: 109
# <All keys matched successfully>
# Timer: 01:08:122025-02-03 03:56:18 | INFO | fairseq.tasks.hubert_pretraining | current directory is /content/HRVC/HRVC
# 2025-02-03 03:56:18 | INFO | fairseq.tasks.hubert_pretraining | HubertPretrainingTask Config {'_name': 'hubert_pretraining', 'data': 'metadata', 'fine_tuning': False, 'labels': ['km'], 'label_dir': 'label', 'label_rate': 50.0, 'sample_rate': 16000, 'normalize': False, 'enable_padding': False, 'max_keep_size': None, 'max_sample_size': 250000, 'min_sample_size': 32000, 'single_target': False, 'random_crop': True, 'pad_audio': False}
# 2025-02-03 03:56:18 | INFO | fairseq.models.hubert.hubert | HubertModel Config: {'_name': 'hubert', 'label_rate': 50.0, 'extractor_mode': default, 'encoder_layers': 12, 'encoder_embed_dim': 768, 'encoder_ffn_embed_dim': 3072, 'encoder_attention_heads': 12, 'activation_fn': gelu, 'layer_type': transformer, 'dropout': 0.1, 'attention_dropout': 0.1, 'activation_dropout': 0.0, 'encoder_layerdrop': 0.05, 'dropout_input': 0.1, 'dropout_features': 0.1, 'final_dim': 256, 'untie_final_proj': True, 'layer_norm_first': False, 'conv_feature_layers': '[(512,10,5)] + [(512,3,2)] * 4 + [(512,2,2)] * 2', 'conv_bias': False, 'logit_temp': 0.1, 'target_glu': False, 'feature_grad_mult': 0.1, 'mask_length': 10, 'mask_prob': 0.8, 'mask_selection': static, 'mask_other': 0.0, 'no_mask_overlap': False, 'mask_min_space': 1, 'mask_channel_length': 10, 'mask_channel_prob': 0.0, 'mask_channel_selection': static, 'mask_channel_other': 0.0, 'no_mask_channel_overlap': False, 'mask_channel_min_space': 1, 'conv_pos': 128, 'conv_pos_groups': 16, 'latent_temp': [2.0, 0.5, 0.999995], 'skip_masked': False, 'skip_nomask': False, 'checkpoint_activations': False, 'required_seq_len_multiple': 2, 'depthwise_conv_kernel_size': 31, 'attn_type': '', 'pos_enc_type': 'abs', 'fp16': False}
# Timer: 01:08:18gin_channels: 256 self.spk_embed_dim: 109
# <All keys matched successfully>
# Timer: 01:09:382025-02-03 03:57:02 | INFO | fairseq.tasks.hubert_pretraining | current directory is /content/HRVC/HRVC
# 2025-02-03 03:57:02 | INFO | fairseq.tasks.hubert_pretraining | HubertPretrainingTask Config {'_name': 'hubert_pretraining', 'data': 'metadata', 'fine_tuning': False, 'labels': ['km'], 'label_dir': 'label', 'label_rate': 50.0, 'sample_rate': 16000, 'normalize': False, 'enable_padding': False, 'max_keep_size': None, 'max_sample_size': 250000, 'min_sample_size': 32000, 'single_target': False, 'random_crop': True, 'pad_audio': False}
# 2025-02-03 03:57:02 | INFO | fairseq.models.hubert.hubert | HubertModel Config: {'_name': 'hubert', 'label_rate': 50.0, 'extractor_mode': default, 'encoder_layers': 12, 'encoder_embed_dim': 768, 'encoder_ffn_embed_dim': 3072, 'encoder_attention_heads': 12, 'activation_fn': gelu, 'layer_type': transformer, 'dropout': 0.1, 'attention_dropout': 0.1, 'activation_dropout': 0.0, 'encoder_layerdrop': 0.05, 'dropout_input': 0.1, 'dropout_features': 0.1, 'final_dim': 256, 'untie_final_proj': True, 'layer_norm_first': False, 'conv_feature_layers': '[(512,10,5)] + [(512,3,2)] * 4 + [(512,2,2)] * 2', 'conv_bias': False, 'logit_temp': 0.1, 'target_glu': False, 'feature_grad_mult': 0.1, 'mask_length': 10, 'mask_prob': 0.8, 'mask_selection': static, 'mask_other': 0.0, 'no_mask_overlap': False, 'mask_min_space': 1, 'mask_channel_length': 10, 'mask_channel_prob': 0.0, 'mask_channel_selection': static, 'mask_channel_other': 0.0, 'no_mask_channel_overlap': False, 'mask_channel_min_space': 1, 'conv_pos': 128, 'conv_pos_groups': 16, 'latent_temp': [2.0, 0.5, 0.999995], 'skip_masked': False, 'skip_nomask': False, 'checkpoint_activations': False, 'required_seq_len_multiple': 2, 'depthwise_conv_kernel_size': 31, 'attn_type': '', 'pos_enc_type': 'abs', 'fp16': False}
# Timer: 01:09:42gin_channels: 256 self.spk_embed_dim: 109
# <All keys matched successfully>
# Timer: 01:11:262025-02-03 03:57:56 | INFO | fairseq.tasks.hubert_pretraining | current directory is /content/HRVC/HRVC
# 2025-02-03 03:57:56 | INFO | fairseq.tasks.hubert_pretraining | HubertPretrainingTask Config {'_name': 'hubert_pretraining', 'data': 'metadata', 'fine_tuning': False, 'labels': ['km'], 'label_dir': 'label', 'label_rate': 50.0, 'sample_rate': 16000, 'normalize': False, 'enable_padding': False, 'max_keep_size': None, 'max_sample_size': 250000, 'min_sample_size': 32000, 'single_target': False, 'random_crop': True, 'pad_audio': False}
# Timer: 01:11:282025-02-03 03:57:56 | INFO | fairseq.models.hubert.hubert | HubertModel Config: {'_name': 'hubert', 'label_rate': 50.0, 'extractor_mode': default, 'encoder_layers': 12, 'encoder_embed_dim': 768, 'encoder_ffn_embed_dim': 3072, 'encoder_attention_heads': 12, 'activation_fn': gelu, 'layer_type': transformer, 'dropout': 0.1, 'attention_dropout': 0.1, 'activation_dropout': 0.0, 'encoder_layerdrop': 0.05, 'dropout_input': 0.1, 'dropout_features': 0.1, 'final_dim': 256, 'untie_final_proj': True, 'layer_norm_first': False, 'conv_feature_layers': '[(512,10,5)] + [(512,3,2)] * 4 + [(512,2,2)] * 2', 'conv_bias': False, 'logit_temp': 0.1, 'target_glu': False, 'feature_grad_mult': 0.1, 'mask_length': 10, 'mask_prob': 0.8, 'mask_selection': static, 'mask_other': 0.0, 'no_mask_overlap': False, 'mask_min_space': 1, 'mask_channel_length': 10, 'mask_channel_prob': 0.0, 'mask_channel_selection': static, 'mask_channel_other': 0.0, 'no_mask_channel_overlap': False, 'mask_channel_min_space': 1, 'conv_pos': 128, 'conv_pos_groups': 16, 'latent_temp': [2.0, 0.5, 0.999995], 'skip_masked': False, 'skip_nomask': False, 'checkpoint_activations': False, 'required_seq_len_multiple': 2, 'depthwise_conv_kernel_size': 31, 'attn_type': '', 'pos_enc_type': 'abs', 'fp16': False}
# Timer: 01:11:32gin_channels: 256 self.spk_embed_dim: 109
# <All keys matched successfully>
# Timer: 01:15:402025-02-03 04:00:02 | INFO | fairseq.tasks.hubert_pretraining | current directory is /content/HRVC/HRVC
# 2025-02-03 04:00:02 | INFO | fairseq.tasks.hubert_pretraining | HubertPretrainingTask Config {'_name': 'hubert_pretraining', 'data': 'metadata', 'fine_tuning': False, 'labels': ['km'], 'label_dir': 'label', 'label_rate': 50.0, 'sample_rate': 16000, 'normalize': False, 'enable_padding': False, 'max_keep_size': None, 'max_sample_size': 250000, 'min_sample_size': 32000, 'single_target': False, 'random_crop': True, 'pad_audio': False}
# 2025-02-03 04:00:02 | INFO | fairseq.models.hubert.hubert | HubertModel Config: {'_name': 'hubert', 'label_rate': 50.0, 'extractor_mode': default, 'encoder_layers': 12, 'encoder_embed_dim': 768, 'encoder_ffn_embed_dim': 3072, 'encoder_attention_heads': 12, 'activation_fn': gelu, 'layer_type': transformer, 'dropout': 0.1, 'attention_dropout': 0.1, 'activation_dropout': 0.0, 'encoder_layerdrop': 0.05, 'dropout_input': 0.1, 'dropout_features': 0.1, 'final_dim': 256, 'untie_final_proj': True, 'layer_norm_first': False, 'conv_feature_layers': '[(512,10,5)] + [(512,3,2)] * 4 + [(512,2,2)] * 2', 'conv_bias': False, 'logit_temp': 0.1, 'target_glu': False, 'feature_grad_mult': 0.1, 'mask_length': 10, 'mask_prob': 0.8, 'mask_selection': static, 'mask_other': 0.0, 'no_mask_overlap': False, 'mask_min_space': 1, 'mask_channel_length': 10, 'mask_channel_prob': 0.0, 'mask_channel_selection': static, 'mask_channel_other': 0.0, 'no_mask_channel_overlap': False, 'mask_channel_min_space': 1, 'conv_pos': 128, 'conv_pos_groups': 16, 'latent_temp': [2.0, 0.5, 0.999995], 'skip_masked': False, 'skip_nomask': False, 'checkpoint_activations': False, 'required_seq_len_multiple': 2, 'depthwise_conv_kernel_size': 31, 'attn_type': '', 'pos_enc_type': 'abs', 'fp16': False}
# Timer: 01:15:44gin_channels: 256 self.spk_embed_dim: 109
# <All keys matched successfully>
# Initiating prediction with a crepe_hop_length of: 128
# Timer: 01:17:382025-02-03 04:01:02 | INFO | fairseq.tasks.hubert_pretraining | current directory is /content/HRVC/HRVC
# 2025-02-03 04:01:02 | INFO | fairseq.tasks.hubert_pretraining | HubertPretrainingTask Config {'_name': 'hubert_pretraining', 'data': 'metadata', 'fine_tuning': False, 'labels': ['km'], 'label_dir': 'label', 'label_rate': 50.0, 'sample_rate': 16000, 'normalize': False, 'enable_padding': False, 'max_keep_size': None, 'max_sample_size': 250000, 'min_sample_size': 32000, 'single_target': False, 'random_crop': True, 'pad_audio': False}
# 2025-02-03 04:01:02 | INFO | fairseq.models.hubert.hubert | HubertModel Config: {'_name': 'hubert', 'label_rate': 50.0, 'extractor_mode': default, 'encoder_layers': 12, 'encoder_embed_dim': 768, 'encoder_ffn_embed_dim': 3072, 'encoder_attention_heads': 12, 'activation_fn': gelu, 'layer_type': transformer, 'dropout': 0.1, 'attention_dropout': 0.1, 'activation_dropout': 0.0, 'encoder_layerdrop': 0.05, 'dropout_input': 0.1, 'dropout_features': 0.1, 'final_dim': 256, 'untie_final_proj': True, 'layer_norm_first': False, 'conv_feature_layers': '[(512,10,5)] + [(512,3,2)] * 4 + [(512,2,2)] * 2', 'conv_bias': False, 'logit_temp': 0.1, 'target_glu': False, 'feature_grad_mult': 0.1, 'mask_length': 10, 'mask_prob': 0.8, 'mask_selection': static, 'mask_other': 0.0, 'no_mask_overlap': False, 'mask_min_space': 1, 'mask_channel_length': 10, 'mask_channel_prob': 0.0, 'mask_channel_selection': static, 'mask_channel_other': 0.0, 'no_mask_channel_overlap': False, 'mask_channel_min_space': 1, 'conv_pos': 128, 'conv_pos_groups': 16, 'latent_temp': [2.0, 0.5, 0.999995], 'skip_masked': False, 'skip_nomask': False, 'checkpoint_activations': False, 'required_seq_len_multiple': 2, 'depthwise_conv_kernel_size': 31, 'attn_type': '', 'pos_enc_type': 'abs', 'fp16': False}
# Timer: 01:17:44gin_channels: 256 self.spk_embed_dim: 109
# <All keys matched successfully>
# Initiating prediction with a crepe_hop_length of: 128
# Timer: 01:18:342025-02-03 04:01:29 | INFO | fairseq.tasks.hubert_pretraining | current directory is /content/HRVC/HRVC
# 2025-02-03 04:01:29 | INFO | fairseq.tasks.hubert_pretraining | HubertPretrainingTask Config {'_name': 'hubert_pretraining', 'data': 'metadata', 'fine_tuning': False, 'labels': ['km'], 'label_dir': 'label', 'label_rate': 50.0, 'sample_rate': 16000, 'normalize': False, 'enable_padding': False, 'max_keep_size': None, 'max_sample_size': 250000, 'min_sample_size': 32000, 'single_target': False, 'random_crop': True, 'pad_audio': False}
# 2025-02-03 04:01:30 | INFO | fairseq.models.hubert.hubert | HubertModel Config: {'_name': 'hubert', 'label_rate': 50.0, 'extractor_mode': default, 'encoder_layers': 12, 'encoder_embed_dim': 768, 'encoder_ffn_embed_dim': 3072, 'encoder_attention_heads': 12, 'activation_fn': gelu, 'layer_type': transformer, 'dropout': 0.1, 'attention_dropout': 0.1, 'activation_dropout': 0.0, 'encoder_layerdrop': 0.05, 'dropout_input': 0.1, 'dropout_features': 0.1, 'final_dim': 256, 'untie_final_proj': True, 'layer_norm_first': False, 'conv_feature_layers': '[(512,10,5)] + [(512,3,2)] * 4 + [(512,2,2)] * 2', 'conv_bias': False, 'logit_temp': 0.1, 'target_glu': False, 'feature_grad_mult': 0.1, 'mask_length': 10, 'mask_prob': 0.8, 'mask_selection': static, 'mask_other': 0.0, 'no_mask_overlap': False, 'mask_min_space': 1, 'mask_channel_length': 10, 'mask_channel_prob': 0.0, 'mask_channel_selection': static, 'mask_channel_other': 0.0, 'no_mask_channel_overlap': False, 'mask_channel_min_space': 1, 'conv_pos': 128, 'conv_pos_groups': 16, 'latent_temp': [2.0, 0.5, 0.999995], 'skip_masked': False, 'skip_nomask': False, 'checkpoint_activations': False, 'required_seq_len_multiple': 2, 'depthwise_conv_kernel_size': 31, 'attn_type': '', 'pos_enc_type': 'abs', 'fp16': False}
# Timer: 01:18:40gin_channels: 256 self.spk_embed_dim: 109
# <All keys matched successfully>
# Timer: 01:18:42Initiating prediction with a crepe_hop_length of: 128
# Timer: 01:22:482025-02-03 04:03:37 | INFO | fairseq.tasks.hubert_pretraining | current directory is /content/HRVC/HRVC
# 2025-02-03 04:03:37 | INFO | fairseq.tasks.hubert_pretraining | HubertPretrainingTask Config {'_name': 'hubert_pretraining', 'data': 'metadata', 'fine_tuning': False, 'labels': ['km'], 'label_dir': 'label', 'label_rate': 50.0, 'sample_rate': 16000, 'normalize': False, 'enable_padding': False, 'max_keep_size': None, 'max_sample_size': 250000, 'min_sample_size': 32000, 'single_target': False, 'random_crop': True, 'pad_audio': False}
# 2025-02-03 04:03:37 | INFO | fairseq.models.hubert.hubert | HubertModel Config: {'_name': 'hubert', 'label_rate': 50.0, 'extractor_mode': default, 'encoder_layers': 12, 'encoder_embed_dim': 768, 'encoder_ffn_embed_dim': 3072, 'encoder_attention_heads': 12, 'activation_fn': gelu, 'layer_type': transformer, 'dropout': 0.1, 'attention_dropout': 0.1, 'activation_dropout': 0.0, 'encoder_layerdrop': 0.05, 'dropout_input': 0.1, 'dropout_features': 0.1, 'final_dim': 256, 'untie_final_proj': True, 'layer_norm_first': False, 'conv_feature_layers': '[(512,10,5)] + [(512,3,2)] * 4 + [(512,2,2)] * 2', 'conv_bias': False, 'logit_temp': 0.1, 'target_glu': False, 'feature_grad_mult': 0.1, 'mask_length': 10, 'mask_prob': 0.8, 'mask_selection': static, 'mask_other': 0.0, 'no_mask_overlap': False, 'mask_min_space': 1, 'mask_channel_length': 10, 'mask_channel_prob': 0.0, 'mask_channel_selection': static, 'mask_channel_other': 0.0, 'no_mask_channel_overlap': False, 'mask_channel_min_space': 1, 'conv_pos': 128, 'conv_pos_groups': 16, 'latent_temp': [2.0, 0.5, 0.999995], 'skip_masked': False, 'skip_nomask': False, 'checkpoint_activations': False, 'required_seq_len_multiple': 2, 'depthwise_conv_kernel_size': 31, 'attn_type': '', 'pos_enc_type': 'abs', 'fp16': False}
# Timer: 01:22:52gin_channels: 256 self.spk_embed_dim: 109
# <All keys matched successfully>
# Timer: 01:22:54Initiating prediction with a crepe_hop_length of: 128
# Timer: 01:24:182025-02-03 04:04:22 | INFO | fairseq.tasks.hubert_pretraining | current directory is /content/HRVC/HRVC
# 2025-02-03 04:04:22 | INFO | fairseq.tasks.hubert_pretraining | HubertPretrainingTask Config {'_name': 'hubert_pretraining', 'data': 'metadata', 'fine_tuning': False, 'labels': ['km'], 'label_dir': 'label', 'label_rate': 50.0, 'sample_rate': 16000, 'normalize': False, 'enable_padding': False, 'max_keep_size': None, 'max_sample_size': 250000, 'min_sample_size': 32000, 'single_target': False, 'random_crop': True, 'pad_audio': False}
# 2025-02-03 04:04:22 | INFO | fairseq.models.hubert.hubert | HubertModel Config: {'_name': 'hubert', 'label_rate': 50.0, 'extractor_mode': default, 'encoder_layers': 12, 'encoder_embed_dim': 768, 'encoder_ffn_embed_dim': 3072, 'encoder_attention_heads': 12, 'activation_fn': gelu, 'layer_type': transformer, 'dropout': 0.1, 'attention_dropout': 0.1, 'activation_dropout': 0.0, 'encoder_layerdrop': 0.05, 'dropout_input': 0.1, 'dropout_features': 0.1, 'final_dim': 256, 'untie_final_proj': True, 'layer_norm_first': False, 'conv_feature_layers': '[(512,10,5)] + [(512,3,2)] * 4 + [(512,2,2)] * 2', 'conv_bias': False, 'logit_temp': 0.1, 'target_glu': False, 'feature_grad_mult': 0.1, 'mask_length': 10, 'mask_prob': 0.8, 'mask_selection': static, 'mask_other': 0.0, 'no_mask_overlap': False, 'mask_min_space': 1, 'mask_channel_length': 10, 'mask_channel_prob': 0.0, 'mask_channel_selection': static, 'mask_channel_other': 0.0, 'no_mask_channel_overlap': False, 'mask_channel_min_space': 1, 'conv_pos': 128, 'conv_pos_groups': 16, 'latent_temp': [2.0, 0.5, 0.999995], 'skip_masked': False, 'skip_nomask': False, 'checkpoint_activations': False, 'required_seq_len_multiple': 2, 'depthwise_conv_kernel_size': 31, 'attn_type': '', 'pos_enc_type': 'abs', 'fp16': False}
# Timer: 01:24:22gin_channels: 256 self.spk_embed_dim: 109
# <All keys matched successfully>
# Timer: 01:24:24Initiating prediction with a crepe_hop_length of: 128
# Timer: 01:47:082025-02-03 04:15:48 | INFO | fairseq.tasks.hubert_pretraining | current directory is /content/HRVC/HRVC
# 2025-02-03 04:15:48 | INFO | fairseq.tasks.hubert_pretraining | HubertPretrainingTask Config {'_name': 'hubert_pretraining', 'data': 'metadata', 'fine_tuning': False, 'labels': ['km'], 'label_dir': 'label', 'label_rate': 50.0, 'sample_rate': 16000, 'normalize': False, 'enable_padding': False, 'max_keep_size': None, 'max_sample_size': 250000, 'min_sample_size': 32000, 'single_target': False, 'random_crop': True, 'pad_audio': False}
# 2025-02-03 04:15:48 | INFO | fairseq.models.hubert.hubert | HubertModel Config: {'_name': 'hubert', 'label_rate': 50.0, 'extractor_mode': default, 'encoder_layers': 12, 'encoder_embed_dim': 768, 'encoder_ffn_embed_dim': 3072, 'encoder_attention_heads': 12, 'activation_fn': gelu, 'layer_type': transformer, 'dropout': 0.1, 'attention_dropout': 0.1, 'activation_dropout': 0.0, 'encoder_layerdrop': 0.05, 'dropout_input': 0.1, 'dropout_features': 0.1, 'final_dim': 256, 'untie_final_proj': True, 'layer_norm_first': False, 'conv_feature_layers': '[(512,10,5)] + [(512,3,2)] * 4 + [(512,2,2)] * 2', 'conv_bias': False, 'logit_temp': 0.1, 'target_glu': False, 'feature_grad_mult': 0.1, 'mask_length': 10, 'mask_prob': 0.8, 'mask_selection': static, 'mask_other': 0.0, 'no_mask_overlap': False, 'mask_min_space': 1, 'mask_channel_length': 10, 'mask_channel_prob': 0.0, 'mask_channel_selection': static, 'mask_channel_other': 0.0, 'no_mask_channel_overlap': False, 'mask_channel_min_space': 1, 'conv_pos': 128, 'conv_pos_groups': 16, 'latent_temp': [2.0, 0.5, 0.999995], 'skip_masked': False, 'skip_nomask': False, 'checkpoint_activations': False, 'required_seq_len_multiple': 2, 'depthwise_conv_kernel_size': 31, 'attn_type': '', 'pos_enc_type': 'abs', 'fp16': False}
# Timer: 01:47:16gin_channels: 256 self.spk_embed_dim: 109
# <All keys matched successfully>
# Timer: 01:47:362025-02-03 04:16:02 | INFO | fairseq.tasks.hubert_pretraining | current directory is /content/HRVC/HRVC
# 2025-02-03 04:16:02 | INFO | fairseq.tasks.hubert_pretraining | HubertPretrainingTask Config {'_name': 'hubert_pretraining', 'data': 'metadata', 'fine_tuning': False, 'labels': ['km'], 'label_dir': 'label', 'label_rate': 50.0, 'sample_rate': 16000, 'normalize': False, 'enable_padding': False, 'max_keep_size': None, 'max_sample_size': 250000, 'min_sample_size': 32000, 'single_target': False, 'random_crop': True, 'pad_audio': False}
# 2025-02-03 04:16:02 | INFO | fairseq.models.hubert.hubert | HubertModel Config: {'_name': 'hubert', 'label_rate': 50.0, 'extractor_mode': default, 'encoder_layers': 12, 'encoder_embed_dim': 768, 'encoder_ffn_embed_dim': 3072, 'encoder_attention_heads': 12, 'activation_fn': gelu, 'layer_type': transformer, 'dropout': 0.1, 'attention_dropout': 0.1, 'activation_dropout': 0.0, 'encoder_layerdrop': 0.05, 'dropout_input': 0.1, 'dropout_features': 0.1, 'final_dim': 256, 'untie_final_proj': True, 'layer_norm_first': False, 'conv_feature_layers': '[(512,10,5)] + [(512,3,2)] * 4 + [(512,2,2)] * 2', 'conv_bias': False, 'logit_temp': 0.1, 'target_glu': False, 'feature_grad_mult': 0.1, 'mask_length': 10, 'mask_prob': 0.8, 'mask_selection': static, 'mask_other': 0.0, 'no_mask_overlap': False, 'mask_min_space': 1, 'mask_channel_length': 10, 'mask_channel_prob': 0.0, 'mask_channel_selection': static, 'mask_channel_other': 0.0, 'no_mask_channel_overlap': False, 'mask_channel_min_space': 1, 'conv_pos': 128, 'conv_pos_groups': 16, 'latent_temp': [2.0, 0.5, 0.999995], 'skip_masked': False, 'skip_nomask': False, 'checkpoint_activations': False, 'required_seq_len_multiple': 2, 'depthwise_conv_kernel_size': 31, 'attn_type': '', 'pos_enc_type': 'abs', 'fp16': False}
# Timer: 01:47:42gin_channels: 256 self.spk_embed_dim: 109
# <All keys matched successfully>
# Timer: 01:54:50Traceback (most recent call last):
#   File "/content/HRVC/HRVC/src/webui.py", line 84, in download_online_model
#     extract_zip(extraction_folder, zip_name)
#   File "/content/HRVC/HRVC/src/webui.py", line 43, in extract_zip
#     with zipfile.ZipFile(zip_name, 'r') as zip_ref:
#   File "/usr/local/lib/python3.9/zipfile.py", line 1268, in __init__
#     self._RealGetContents()
#   File "/usr/local/lib/python3.9/zipfile.py", line 1335, in _RealGetContents
#     raise BadZipFile("File is not a zip file")
# zipfile.BadZipFile: File is not a zip file
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/gradio/queueing.py", line 407, in call_prediction
#     output = await route_utils.call_process_api(
#   File "/usr/local/lib/python3.9/site-packages/gradio/route_utils.py", line 226, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/usr/local/lib/python3.9/site-packages/gradio/blocks.py", line 1550, in process_api
#     result = await self.call_function(
#   File "/usr/local/lib/python3.9/site-packages/gradio/blocks.py", line 1185, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "/usr/local/lib/python3.9/site-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/usr/local/lib/python3.9/site-packages/anyio/_backends/_asyncio.py", line 2364, in run_sync_in_worker_thread
#     return await future
#   File "/usr/local/lib/python3.9/site-packages/anyio/_backends/_asyncio.py", line 864, in run
#     result = context.run(func, *args)
#   File "/usr/local/lib/python3.9/site-packages/gradio/utils.py", line 661, in wrapper
#     response = f(*args, **kwargs)
#   File "/content/HRVC/HRVC/src/webui.py", line 88, in download_online_model
#     raise gr.Error(str(e))
# gradio.exceptions.Error: 'File is not a zip file'
# Timer: 01:54:56Traceback (most recent call last):
#   File "/content/HRVC/HRVC/src/webui.py", line 76, in download_online_model
#     raise gr.Error(f'Voice model directory {dir_name} already exists! Choose a different name for your voice model.')
# gradio.exceptions.Error: 'Voice model directory Saya already exists! Choose a different name for your voice model.'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/gradio/queueing.py", line 407, in call_prediction
#     output = await route_utils.call_process_api(
#   File "/usr/local/lib/python3.9/site-packages/gradio/route_utils.py", line 226, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/usr/local/lib/python3.9/site-packages/gradio/blocks.py", line 1550, in process_api
#     result = await self.call_function(
#   File "/usr/local/lib/python3.9/site-packages/gradio/blocks.py", line 1185, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "/usr/local/lib/python3.9/site-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/usr/local/lib/python3.9/site-packages/anyio/_backends/_asyncio.py", line 2364, in run_sync_in_worker_thread
#     return await future
#   File "/usr/local/lib/python3.9/site-packages/anyio/_backends/_asyncio.py", line 864, in run
#     result = context.run(func, *args)
#   File "/usr/local/lib/python3.9/site-packages/gradio/utils.py", line 661, in wrapper
#     response = f(*args, **kwargs)
#   File "/content/HRVC/HRVC/src/webui.py", line 88, in download_online_model
#     raise gr.Error(str(e))
# gradio.exceptions.Error: "'Voice model directory Saya already exists! Choose a different name for your voice model.'"
# Timer: 01:55:12Traceback (most recent call last):
#   File "/content/HRVC/HRVC/src/webui.py", line 84, in download_online_model
#     extract_zip(extraction_folder, zip_name)
#   File "/content/HRVC/HRVC/src/webui.py", line 43, in extract_zip
#     with zipfile.ZipFile(zip_name, 'r') as zip_ref:
#   File "/usr/local/lib/python3.9/zipfile.py", line 1268, in __init__
#     self._RealGetContents()
#   File "/usr/local/lib/python3.9/zipfile.py", line 1335, in _RealGetContents
#     raise BadZipFile("File is not a zip file")
# zipfile.BadZipFile: File is not a zip file
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/gradio/queueing.py", line 407, in call_prediction
#     output = await route_utils.call_process_api(
#   File "/usr/local/lib/python3.9/site-packages/gradio/route_utils.py", line 226, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/usr/local/lib/python3.9/site-packages/gradio/blocks.py", line 1550, in process_api
#     result = await self.call_function(
#   File "/usr/local/lib/python3.9/site-packages/gradio/blocks.py", line 1185, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "/usr/local/lib/python3.9/site-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/usr/local/lib/python3.9/site-packages/anyio/_backends/_asyncio.py", line 2364, in run_sync_in_worker_thread
#     return await future
#   File "/usr/local/lib/python3.9/site-packages/anyio/_backends/_asyncio.py", line 864, in run
#     result = context.run(func, *args)
#   File "/usr/local/lib/python3.9/site-packages/gradio/utils.py", line 661, in wrapper
#     response = f(*args, **kwargs)
#   File "/content/HRVC/HRVC/src/webui.py", line 88, in download_online_model
#     raise gr.Error(str(e))
# gradio.exceptions.Error: 'File is not a zip file'
# Timer: 01:56:462025-02-03 04:20:38 | INFO | fairseq.tasks.hubert_pretraining | current directory is /content/HRVC/HRVC
# 2025-02-03 04:20:38 | INFO | fairseq.tasks.hubert_pretraining | HubertPretrainingTask Config {'_name': 'hubert_pretraining', 'data': 'metadata', 'fine_tuning': False, 'labels': ['km'], 'label_dir': 'label', 'label_rate': 50.0, 'sample_rate': 16000, 'normalize': False, 'enable_padding': False, 'max_keep_size': None, 'max_sample_size': 250000, 'min_sample_size': 32000, 'single_target': False, 'random_crop': True, 'pad_audio': False}
# 2025-02-03 04:20:38 | INFO | fairseq.models.hubert.hubert | HubertModel Config: {'_name': 'hubert', 'label_rate': 50.0, 'extractor_mode': default, 'encoder_layers': 12, 'encoder_embed_dim': 768, 'encoder_ffn_embed_dim': 3072, 'encoder_attention_heads': 12, 'activation_fn': gelu, 'layer_type': transformer, 'dropout': 0.1, 'attention_dropout': 0.1, 'activation_dropout': 0.0, 'encoder_layerdrop': 0.05, 'dropout_input': 0.1, 'dropout_features': 0.1, 'final_dim': 256, 'untie_final_proj': True, 'layer_norm_first': False, 'conv_feature_layers': '[(512,10,5)] + [(512,3,2)] * 4 + [(512,2,2)] * 2', 'conv_bias': False, 'logit_temp': 0.1, 'target_glu': False, 'feature_grad_mult': 0.1, 'mask_length': 10, 'mask_prob': 0.8, 'mask_selection': static, 'mask_other': 0.0, 'no_mask_overlap': False, 'mask_min_space': 1, 'mask_channel_length': 10, 'mask_channel_prob': 0.0, 'mask_channel_selection': static, 'mask_channel_other': 0.0, 'no_mask_channel_overlap': False, 'mask_channel_min_space': 1, 'conv_pos': 128, 'conv_pos_groups': 16, 'latent_temp': [2.0, 0.5, 0.999995], 'skip_masked': False, 'skip_nomask': False, 'checkpoint_activations': False, 'required_seq_len_multiple': 2, 'depthwise_conv_kernel_size': 31, 'attn_type': '', 'pos_enc_type': 'abs', 'fp16': False}
# Timer: 01:56:52gin_channels: 256 self.spk_embed_dim: 109
# <All keys matched successfully>
# Timer: 01:56:54Traceback (most recent call last):
#   File "/content/HRVC/HRVC/src/main.py", line 291, in song_cover_pipeline
#     voice_change(voice_model, main_vocals_dereverb_path, ai_vocals_path, pitch_change, f0_method, index_rate, filter_radius, rms_mix_rate, protect, crepe_hop_length, is_webui)
#   File "/content/HRVC/HRVC/src/main.py", line 201, in voice_change
#     rvc_infer(rvc_index_path, index_rate, vocals_path, output_path, pitch_change, f0_method, cpt, version, net_g, filter_radius, tgt_sr, rms_mix_rate, protect, crepe_hop_length, vc, hubert_model)
#   File "/content/HRVC/HRVC/src/rvc.py", line 150, in rvc_infer
#     audio_opt = vc.pipeline(hubert_model, net_g, 0, audio, input_path, times, pitch_change, f0_method, index_path, index_rate, if_f0, filter_radius, tgt_sr, 0, rms_mix_rate, version, protect, crepe_hop_length)
#   File "/content/HRVC/HRVC/src/vc_infer_pipeline.py", line 606, in pipeline
#     self.vc(
#   File "/content/HRVC/HRVC/src/vc_infer_pipeline.py", line 424, in vc
#     npy = np.sum(big_npy[ix] * np.expand_dims(weight, axis=2), axis=1)
# IndexError: index -1 is out of bounds for axis 0 with size 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/gradio/queueing.py", line 407, in call_prediction
#     output = await route_utils.call_process_api(
#   File "/usr/local/lib/python3.9/site-packages/gradio/route_utils.py", line 226, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/usr/local/lib/python3.9/site-packages/gradio/blocks.py", line 1550, in process_api
#     result = await self.call_function(
#   File "/usr/local/lib/python3.9/site-packages/gradio/blocks.py", line 1185, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "/usr/local/lib/python3.9/site-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/usr/local/lib/python3.9/site-packages/anyio/_backends/_asyncio.py", line 2364, in run_sync_in_worker_thread
#     return await future
#   File "/usr/local/lib/python3.9/site-packages/anyio/_backends/_asyncio.py", line 864, in run
#     result = context.run(func, *args)
#   File "/usr/local/lib/python3.9/site-packages/gradio/utils.py", line 661, in wrapper
#     response = f(*args, **kwargs)
#   File "/content/HRVC/HRVC/src/main.py", line 316, in song_cover_pipeline
#     raise_exception(str(e), is_webui)
#   File "/content/HRVC/HRVC/src/main.py", line 83, in raise_exception
#     raise gr.Error(error_msg)
# gradio.exceptions.Error: 'index -1 is out of bounds for axis 0 with size 0'
# Timer: 01:59:182025-02-03 04:21:54 | INFO | fairseq.tasks.hubert_pretraining | current directory is /content/HRVC/HRVC
# 2025-02-03 04:21:54 | INFO | fairseq.tasks.hubert_pretraining | HubertPretrainingTask Config {'_name': 'hubert_pretraining', 'data': 'metadata', 'fine_tuning': False, 'labels': ['km'], 'label_dir': 'label', 'label_rate': 50.0, 'sample_rate': 16000, 'normalize': False, 'enable_padding': False, 'max_keep_size': None, 'max_sample_size': 250000, 'min_sample_size': 32000, 'single_target': False, 'random_crop': True, 'pad_audio': False}
# 2025-02-03 04:21:54 | INFO | fairseq.models.hubert.hubert | HubertModel Config: {'_name': 'hubert', 'label_rate': 50.0, 'extractor_mode': default, 'encoder_layers': 12, 'encoder_embed_dim': 768, 'encoder_ffn_embed_dim': 3072, 'encoder_attention_heads': 12, 'activation_fn': gelu, 'layer_type': transformer, 'dropout': 0.1, 'attention_dropout': 0.1, 'activation_dropout': 0.0, 'encoder_layerdrop': 0.05, 'dropout_input': 0.1, 'dropout_features': 0.1, 'final_dim': 256, 'untie_final_proj': True, 'layer_norm_first': False, 'conv_feature_layers': '[(512,10,5)] + [(512,3,2)] * 4 + [(512,2,2)] * 2', 'conv_bias': False, 'logit_temp': 0.1, 'target_glu': False, 'feature_grad_mult': 0.1, 'mask_length': 10, 'mask_prob': 0.8, 'mask_selection': static, 'mask_other': 0.0, 'no_mask_overlap': False, 'mask_min_space': 1, 'mask_channel_length': 10, 'mask_channel_prob': 0.0, 'mask_channel_selection': static, 'mask_channel_other': 0.0, 'no_mask_channel_overlap': False, 'mask_channel_min_space': 1, 'conv_pos': 128, 'conv_pos_groups': 16, 'latent_temp': [2.0, 0.5, 0.999995], 'skip_masked': False, 'skip_nomask': False, 'checkpoint_activations': False, 'required_seq_len_multiple': 2, 'depthwise_conv_kernel_size': 31, 'attn_type': '', 'pos_enc_type': 'abs', 'fp16': False}
# Timer: 01:59:22gin_channels: 256 self.spk_embed_dim: 109
# <All keys matched successfully>
# Timer: 01:59:26Traceback (most recent call last):
#   File "/content/HRVC/HRVC/src/main.py", line 291, in song_cover_pipeline
#     voice_change(voice_model, main_vocals_dereverb_path, ai_vocals_path, pitch_change, f0_method, index_rate, filter_radius, rms_mix_rate, protect, crepe_hop_length, is_webui)
#   File "/content/HRVC/HRVC/src/main.py", line 201, in voice_change
#     rvc_infer(rvc_index_path, index_rate, vocals_path, output_path, pitch_change, f0_method, cpt, version, net_g, filter_radius, tgt_sr, rms_mix_rate, protect, crepe_hop_length, vc, hubert_model)
#   File "/content/HRVC/HRVC/src/rvc.py", line 150, in rvc_infer
#     audio_opt = vc.pipeline(hubert_model, net_g, 0, audio, input_path, times, pitch_change, f0_method, index_path, index_rate, if_f0, filter_radius, tgt_sr, 0, rms_mix_rate, version, protect, crepe_hop_length)
#   File "/content/HRVC/HRVC/src/vc_infer_pipeline.py", line 606, in pipeline
#     self.vc(
#   File "/content/HRVC/HRVC/src/vc_infer_pipeline.py", line 424, in vc
#     npy = np.sum(big_npy[ix] * np.expand_dims(weight, axis=2), axis=1)
# IndexError: index -1 is out of bounds for axis 0 with size 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/gradio/queueing.py", line 407, in call_prediction
#     output = await route_utils.call_process_api(
#   File "/usr/local/lib/python3.9/site-packages/gradio/route_utils.py", line 226, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/usr/local/lib/python3.9/site-packages/gradio/blocks.py", line 1550, in process_api
#     result = await self.call_function(
#   File "/usr/local/lib/python3.9/site-packages/gradio/blocks.py", line 1185, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "/usr/local/lib/python3.9/site-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/usr/local/lib/python3.9/site-packages/anyio/_backends/_asyncio.py", line 2364, in run_sync_in_worker_thread
#     return await future
#   File "/usr/local/lib/python3.9/site-packages/anyio/_backends/_asyncio.py", line 864, in run
#     result = context.run(func, *args)
#   File "/usr/local/lib/python3.9/site-packages/gradio/utils.py", line 661, in wrapper
#     response = f(*args, **kwargs)
#   File "/content/HRVC/HRVC/src/main.py", line 316, in song_cover_pipeline
#     raise_exception(str(e), is_webui)
#   File "/content/HRVC/HRVC/src/main.py", line 83, in raise_exception
#     raise gr.Error(error_msg)
# gradio.exceptions.Error: 'index -1 is out of bounds for axis 0 with size 0'
# Timer: 02:22:582025-02-03 04:33:45 | INFO | fairseq.tasks.hubert_pretraining | current directory is /content/HRVC/HRVC
# 2025-02-03 04:33:45 | INFO | fairseq.tasks.hubert_pretraining | HubertPretrainingTask Config {'_name': 'hubert_pretraining', 'data': 'metadata', 'fine_tuning': False, 'labels': ['km'], 'label_dir': 'label', 'label_rate': 50.0, 'sample_rate': 16000, 'normalize': False, 'enable_padding': False, 'max_keep_size': None, 'max_sample_size': 250000, 'min_sample_size': 32000, 'single_target': False, 'random_crop': True, 'pad_audio': False}
# 2025-02-03 04:33:45 | INFO | fairseq.models.hubert.hubert | HubertModel Config: {'_name': 'hubert', 'label_rate': 50.0, 'extractor_mode': default, 'encoder_layers': 12, 'encoder_embed_dim': 768, 'encoder_ffn_embed_dim': 3072, 'encoder_attention_heads': 12, 'activation_fn': gelu, 'layer_type': transformer, 'dropout': 0.1, 'attention_dropout': 0.1, 'activation_dropout': 0.0, 'encoder_layerdrop': 0.05, 'dropout_input': 0.1, 'dropout_features': 0.1, 'final_dim': 256, 'untie_final_proj': True, 'layer_norm_first': False, 'conv_feature_layers': '[(512,10,5)] + [(512,3,2)] * 4 + [(512,2,2)] * 2', 'conv_bias': False, 'logit_temp': 0.1, 'target_glu': False, 'feature_grad_mult': 0.1, 'mask_length': 10, 'mask_prob': 0.8, 'mask_selection': static, 'mask_other': 0.0, 'no_mask_overlap': False, 'mask_min_space': 1, 'mask_channel_length': 10, 'mask_channel_prob': 0.0, 'mask_channel_selection': static, 'mask_channel_other': 0.0, 'no_mask_channel_overlap': False, 'mask_channel_min_space': 1, 'conv_pos': 128, 'conv_pos_groups': 16, 'latent_temp': [2.0, 0.5, 0.999995], 'skip_masked': False, 'skip_nomask': False, 'checkpoint_activations': False, 'required_seq_len_multiple': 2, 'depthwise_conv_kernel_size': 31, 'attn_type': '', 'pos_enc_type': 'abs', 'fp16': False}
# Timer: 02:23:04gin_channels: 256 self.spk_embed_dim: 109
# <All keys matched successfully>
# Timer: 02:39:02
